# %%
cd /content/drive/My Drive/GSoC2020/audio_visual_emotion/GSoC2020/
# Out:
# /content/drive/My Drive/GSoC2020/audio_visual_emotion/GSoC2020

# %%
import numpy as np
import os
import sys

from keras.models import Sequential, Model
from keras.layers.core import Dense, Activation
from keras.layers import LSTM, Input, Flatten, Embedding, Convolution1D,Dropout, Concatenate
from keras.optimizers import SGD, Adam, RMSprop

from scipy import signal
from sklearn.preprocessing import label_binarize

import pickle
from features import *
from helper import *

# %% [markdown]
# ## Loading data

# %%
code_path = os.path.dirname(os.path.realpath(os.getcwd()))
emotions_used = np.array(['ang', 'exc', 'neu', 'sad'])
#data_path = code_path + "/../data/sessions/"
data_path = "../../Data/IEMOCAP/"
framerate = 16000

# %%
# Load IEMOCAP data
with open(data_path + '/../'+'data_collected.pickle', 'rb') as handle:
    data2 = pickle.load(handle)

# %%
# TODO: understand the processing
# 
fs = 16e3 # Framerate is 16000
f, t, Sxx = signal.spectrogram(data2[900]['signal'], fs, nperseg=400)
print(data2[900]['signal'].shape)
print(Sxx.shape)
Sxx, _ = pad_sequence_into_array(Sxx, maxlen=300) # Crop a fixed size from the audio signal
Sxx.shape #
# Out:
# (150240,)
# (201, 429)
# (201, 300)

# %%
x_train_speech = []
fs = 16e3
counter = 0
for ses_mod in data2:
    x_speech = ses_mod['signal']
    f, t, Sxx = signal.spectrogram(x_speech, fs, nperseg=400)
    Sxx, _ = pad_sequence_into_array(Sxx, maxlen=300)
    x_train_speech.append(Sxx)
    counter+=1
    if(counter%100==0):
        print(counter)
    
x_train_speech = np.array(x_train_speech)
x_train_speech.shape # (numberOfSample, )
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# (950, 201, 300)

# %%
Y=[]
for ses_mod in data2:
    Y.append(ses_mod['emotion'])
    
Y = label_binarize(Y,emotions_used)

Y.shape
# Out:
# (950, 4)

# %% [markdown]
# ## Training Audio-only models

# %%
# Since here we only use Session1, small network is used
# There is only temporal info, so conv1D is used

model = Sequential()
model.add(Convolution1D(32, 3, border_mode='same', input_shape=(201, 300)))
model.add(Dropout(0.2))
model.add(Activation('relu'))
model.add(Convolution1D(32, 3, border_mode='same'))
model.add(Dropout(0.2))
model.add(Activation('relu'))
model.add(Flatten())
model.add(Dropout(0.2))
model.add(Dense(128))
model.add(Activation('relu')) 
model.add(Dropout(0.2))
model.add(Dense(4))
model.add(Activation('softmax'))

#sgd = optimizers.SGD(lr=0.001, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy',optimizer='adam' ,metrics=['acc'])

model.summary()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: Update your `Conv1D` call to the Keras 2 API: `Conv1D(32, 3, input_shape=(201, 300), padding="same")`
#   after removing the cwd from sys.path.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1 (Conv1D)            (None, 201, 32)           28832
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 201, 32)           0
# _________________________________________________________________
# activation_1 (Activation)    (None, 201, 32)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 201, 32)           3104
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 201, 32)           0
# _________________________________________________________________
# activation_2 (Activation)    (None, 201, 32)           0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 6432)              0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 6432)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               823424
# _________________________________________________________________
# activation_3 (Activation)    (None, 128)               0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 516
# _________________________________________________________________
# activation_4 (Activation)    (None, 4)                 0
# =================================================================
# Total params: 855,876
# Trainable params: 855,876
# Non-trainable params: 0
# _________________________________________________________________
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: UserWarning: Update your `Conv1D` call to the Keras 2 API: `Conv1D(32, 3, padding="same")`
#   import sys

# %%
hist = model.fit(x_train_speech, Y, 
                 batch_size=100, nb_epoch=50, verbose=1, shuffle = True, 
                 validation_split=0.2)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   This is separate from the ipykernel package so we can avoid doing imports until
#
# Epoch 40/50
# 760/760 [==============================] - 1s 2ms/step - loss: 69.9145 - acc: 0.5868 - val_loss: 747.7202 - val_acc: 0.3579
# Epoch 41/50
# 760/760 [==============================] - 1s 2ms/step - loss: 62.6404 - acc: 0.6158 - val_loss: 839.3948 - val_acc: 0.3421
# Epoch 42/50
# 760/760 [==============================] - 1s 2ms/step - loss: 103.2148 - acc: 0.6105 - val_loss: 864.9467 - val_acc: 0.3526
# Epoch 43/50
# 760/760 [==============================] - 1s 2ms/step - loss: 36.4759 - acc: 0.5855 - val_loss: 849.4904 - val_acc: 0.3526
# Epoch 44/50
# 760/760 [==============================] - 1s 2ms/step - loss: 58.7279 - acc: 0.6263 - val_loss: 875.5854 - val_acc: 0.3368
# Epoch 45/50
# 760/760 [==============================] - 1s 2ms/step - loss: 49.0680 - acc: 0.6013 - val_loss: 844.5690 - val_acc: 0.3579
# Epoch 46/50
# 760/760 [==============================] - 1s 2ms/step - loss: 41.0699 - acc: 0.6013 - val_loss: 753.3840 - val_acc: 0.3421
# Epoch 47/50
# 760/760 [==============================] - 1s 2ms/step - loss: 43.3612 - acc: 0.5868 - val_loss: 715.0726 - val_acc: 0.3579
# Epoch 48/50
# 760/760 [==============================] - 1s 2ms/step - loss: 64.1064 - acc: 0.6342 - val_loss: 717.0434 - val_acc: 0.3737
# Epoch 49/50
# 760/760 [==============================] - 1s 2ms/step - loss: 49.9050 - acc: 0.6000 - val_loss: 676.7487 - val_acc: 0.3789
# Epoch 50/50
# 760/760 [==============================] - 1s 2ms/step - loss: 41.3447 - acc: 0.6145 - val_loss: 626.9974 - val_acc: 0.3789

# %%
def lstm_model(optimizer='Adadelta'):
    model = Sequential()
    model.add(LSTM(128, return_sequences=True, input_shape=(201, 300)))
    model.add(LSTM(256, return_sequences=False))
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dense(4))
    model.add(Activation('softmax'))

    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

    return model

model = lstm_model()
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 201, 128)          219648
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 256)               394240
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               131584
# _________________________________________________________________
# activation_5 (Activation)    (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 2052
# _________________________________________________________________
# activation_6 (Activation)    (None, 4)                 0
# =================================================================
# Total params: 747,524
# Trainable params: 747,524
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(x_train_speech, Y, 
                 batch_size=100, nb_epoch=40, verbose=1, shuffle = True, 
                 validation_split=0.2)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   This is separate from the ipykernel package so we can avoid doing imports until
# Train on 760 samples, validate on 190 samples
# Epoch 1/40
# 760/760 [==============================] - 7s 9ms/step - loss: 1.3476 - accuracy: 0.4342 - val_loss: 1.3952 - val_accuracy: 0.2474
# Epoch 2/40
# 760/760 [==============================] - 5s 7ms/step - loss: 1.2303 - accuracy: 0.5132 - val_loss: 1.4228 - val_accuracy: 0.3684
# Epoch 3/40
# 760/760 [==============================] - 5s 7ms/step - loss: 1.1815 - accuracy: 0.5329 - val_loss: 1.5162 - val_accuracy: 0.2579
# Epoch 4/40
# 760/760 [==============================] - 5s 7ms/step - loss: 1.0975 - accuracy: 0.5553 - val_loss: 1.2402 - val_accuracy: 0.3421
# Epoch 5/40
# 760/760 [==============================] - 5s 7ms/step - loss: 1.0043 - accuracy: 0.5961 - val_loss: 1.3174 - val_accuracy: 0.3474
# Epoch 6/40
# 760/760 [==============================] - 5s 7ms/step - loss: 0.9341 - accuracy: 0.6184 - val_loss: 1.3138 - val_accuracy: 0.3632
# Epoch 7/40
# 760/760 [==============================] - 5s 7ms/step - loss: 0.9152 - accuracy: 0.6184 - val_loss: 1.4442 - val_accuracy: 0.3789
# Epoch 8/40
# 760/760 [==============================] - 5s 7ms/step - loss: 0.8419 - accuracy: 0.6461 - val_loss: 1.5629 - val_accuracy: 0.4053
# Epoch 9/40
# 760/760 [==============================] - 5s 7ms/step - loss: 0.8991 - accuracy: 0.6184 - val_loss: 1.3533 - val_accuracy: 0.3579
# Epoch 10/40
# 760/760 [==============================] - 5s 7ms/step - loss: 0.7771 - accuracy: 0.6816 - val_loss: 1.5490 - val_accuracy: 0.4053
# Epoch 11/40
# 760/760 [==============================] - 5s 7ms/step - loss: 0.8380 - accuracy: 0.6553 - val_loss: 1.3694 - val_accuracy: 0.3579
# Epoch 12/40
# 760/760 [==============================] - 5s 7ms/step - loss: 0.8090 - accuracy: 0.6618 - val_loss: 1.5994 - val_accuracy: 0.3421
# Epoch 13/40
# 760/760 [==============================] - 5s 7ms/step - loss: 0.7185 - accuracy: 0.7145 - val_loss: 1.7750 - val_accuracy: 0.3053
# Epoch 14/40
# 760/760 [==============================] - 5s 7ms/step - loss: 0.8811 - accuracy: 0.6474 - val_loss: 1.7018 - val_accuracy: 0.3632
# Epoch 15/40
# 760/760 [==============================] - 5s 7ms/step - loss: 0.6559 - accuracy: 0.7289 - val_loss: 1.7318 - val_accuracy: 0.3474
# Epoch 16/40
# 760/760 [==============================] - 5s 7ms/step - loss: 0.6520 - accuracy: 0.7184 - val_loss: 1.7803 - val_accuracy: 0.3684
# Epoch 17/40
# 760/760 [==============================] - 5s 7ms/step - loss: 0.6343 - accuracy: 0.7342 - val_loss: 1.7532 - val_accuracy: 0.3842
# Epoch 18/40
# 760/760 [==============================] - 5s 7ms/step - loss: 0.6236 - accuracy: 0.7474 - val_loss: 1.8317 - val_accuracy: 0.3789
# Epoch 19/40
# 760/760 [==============================] - 5s 7ms/step - loss: 0.5933 - accuracy: 0.7566 - val_loss: 1.8905 - val_accuracy: 0.3842
# Epoch 20/40
# 760/760 [==============================] - 5s 7ms/step - loss: 0.6013 - accuracy: 0.7539 - val_loss: 2.1015 - val_accuracy: 0.3263
# Epoch 21/40
# 760/760 [==============================] - 5s 7ms/step - loss: 0.5938 - accuracy: 0.7250 - val_loss: 2.2121 - val_accuracy: 0.3421
# Epoch 22/40
# 760/760 [==============================] - 5s 7ms/step - loss: 0.5781 - accuracy: 0.7618 - val_loss: 2.0125 - val_accuracy: 0.3895
# Epoch 23/40
# 760/760 [==============================] - 5s 7ms/step - loss: 0.5180 - accuracy: 0.7711 - val_loss: 2.2451 - val_accuracy: 0.3789
# Epoch 24/40
# 760/760 [==============================] - 5s 7ms/step - loss: 0.5583 - accuracy: 0.7329 - val_loss: 1.9227 - val_accuracy: 0.3632
# Epoch 25/40
# 760/760 [==============================] - 5s 7ms/step - loss: 0.5380 - accuracy: 0.7461 - val_loss: 2.0515 - val_accuracy: 0.4053
# Epoch 26/40
# 760/760 [==============================] - 5s 7ms/step - loss: 0.5399 - accuracy: 0.7684 - val_loss: 2.0440 - val_accuracy: 0.3842
# Epoch 27/40
# 760/760 [==============================] - 5s 7ms/step - loss: 0.5071 - accuracy: 0.7724 - val_loss: 2.1922 - val_accuracy: 0.3842
# Epoch 28/40
# 760/760 [==============================] - 5s 7ms/step - loss: 0.4535 - accuracy: 0.7947 - val_loss: 2.3291 - val_accuracy: 0.3947
# Epoch 29/40
# 760/760 [==============================] - 5s 7ms/step - loss: 0.4249 - accuracy: 0.7947 - val_loss: 2.2238 - val_accuracy: 0.3684
# Epoch 30/40
# 760/760 [==============================] - 5s 7ms/step - loss: 0.5080 - accuracy: 0.7526 - val_loss: 2.4618 - val_accuracy: 0.3737
# Epoch 31/40
# 760/760 [==============================] - 5s 7ms/step - loss: 0.5171 - accuracy: 0.7724 - val_loss: 2.1765 - val_accuracy: 0.4105
# Epoch 32/40
# 760/760 [==============================] - 5s 7ms/step - loss: 0.4279 - accuracy: 0.7868 - val_loss: 2.0137 - val_accuracy: 0.4211
# Epoch 33/40
# 760/760 [==============================] - 5s 7ms/step - loss: 0.4205 - accuracy: 0.7645 - val_loss: 2.2343 - val_accuracy: 0.4211
# Epoch 34/40
# 760/760 [==============================] - 5s 7ms/step - loss: 0.3623 - accuracy: 0.8237 - val_loss: 2.2975 - val_accuracy: 0.4211
# Epoch 35/40
# 760/760 [==============================] - 5s 7ms/step - loss: 0.4412 - accuracy: 0.7934 - val_loss: 2.2857 - val_accuracy: 0.4053
# Epoch 36/40
# 760/760 [==============================] - 5s 7ms/step - loss: 0.3999 - accuracy: 0.7855 - val_loss: 2.2254 - val_accuracy: 0.4211
# Epoch 37/40
# 760/760 [==============================] - 5s 7ms/step - loss: 0.3343 - accuracy: 0.8211 - val_loss: 2.5703 - val_accuracy: 0.3579
# Epoch 38/40
# 760/760 [==============================] - 5s 7ms/step - loss: 0.3872 - accuracy: 0.8026 - val_loss: 2.4384 - val_accuracy: 0.3947
# Epoch 39/40
# 760/760 [==============================] - 5s 7ms/step - loss: 0.2923 - accuracy: 0.8513 - val_loss: 2.5260 - val_accuracy: 0.3895
# Epoch 40/40
# 760/760 [==============================] - 5s 7ms/step - loss: 0.3492 - accuracy: 0.8158 - val_loss: 2.6450 - val_accuracy: 0.4263

# %%
def calculate_features(frames, freq, options):
    window_sec = 0.2
    window_n = int(freq * window_sec)

    st_f = stFeatureExtraction(frames, freq, window_n, window_n / 2)

    if st_f.shape[1] > 2:
        i0 = 1
        i1 = st_f.shape[1] - 1
        if i1 - i0 < 1:
            i1 = i0 + 1
        
        deriv_st_f = np.zeros((st_f.shape[0], i1 - i0), dtype=float)
        for i in range(i0, i1):
            i_left = i - 1
            i_right = i + 1
            deriv_st_f[:st_f.shape[0], i - i0] = st_f[:, i]
        return deriv_st_f
    elif st_f.shape[1] == 2:
        deriv_st_f = np.zeros((st_f.shape[0], 1), dtype=float)
        deriv_st_f[:st_f.shape[0], 0] = st_f[:, 0]
        return deriv_st_f
    else:
        deriv_st_f = np.zeros((st_f.shape[0], 1), dtype=float)
        deriv_st_f[:st_f.shape[0], 0] = st_f[:, 0]
        return deriv_st_f

# %%
x_train_feat = []

counter = 0
for ses_mod in data2:
    x_head = ses_mod['signal']
    st_features = calculate_features(x_head, framerate, None)
    st_features, _ = pad_sequence_into_array(st_features, maxlen=100)
    x_train_feat.append( st_features.T )
    counter+=1
    if(counter%100==0):
        print(counter)
    
x_train_feat = np.array(x_train_feat)
x_train_feat.shape
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# (950, 100, 34)

# %%
def linear_model_combined(optimizer='Adam'):
    modela = Sequential()
    modela.add(Flatten(input_shape=(100, 34)))
    modela.add(Dense(1024))
    modela.add(Activation('relu'))
    modela.add(Dense(256))
    
    modelb = Sequential()
    #model.add(Embedding(2737, 128, input_length=MAX_SEQUENCE_LENGTH))
    modelb.add(Convolution1D(256, 3, border_mode='same', input_shape=(201, 300)))
    modelb.add(Dropout(0.2))
    modelb.add(Activation('relu'))
    modelb.add(Convolution1D(128, 3, border_mode='same'))
    modelb.add(Dropout(0.2))
    modelb.add(Activation('relu'))
    modelb.add(Convolution1D(64, 3, border_mode='same'))
    modelb.add(Dropout(0.2))
    modelb.add(Activation('relu'))
    modelb.add(Convolution1D(32, 3, border_mode='same'))
    modelb.add(Dropout(0.2))
    modelb.add(Activation('relu'))
    modelb.add(Flatten())
    modelb.add(Dense(256))



    model_combined = concatenate([modela.output, modelb.output], axis=-1)
    model_combined = Dense(4, activation='relu')(model_combined)
    output = Dense(4, activation="softmax")(model_combined)
    
    model = Model(inputs=[modela.input, modelb.input], outputs=output)

    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

    return model
